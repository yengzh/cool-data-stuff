# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# This is normal text
#
# # This is a Python code
# print("Hello World")

# %%
# !pip install pandas

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
# Create Data
Data = { 
        "Student_name" : ["Yeng", "Heesoo", "Victoria", "Cao", "Luke"],
        "Student_ID" : [1000,1001,1002,1003,1004],
        "Course_Name" :["Goon1","Goon2","Goon3","Goon4","Goon5"]
}

# %%
data.keys()

# %%
data.values()

# %%
df = pd.DataFrame(Data)

# %%
df
# Out:
#   Student_name  Student_ID Course_Name
# 0         Yeng        1000       Goon1
# 1       Heesoo        1001       Goon2
# 2     Victoria        1002       Goon3
# 3          Cao        1003       Goon4
# 4         Luke        1004       Goon5

# %%
df_1 = pd.DataFrame(
{"a" : [4, 5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = [1, 2, 3])

# %%
df_1
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info
# Out:
# <bound method DataFrame.info of   Student_name  Student_ID Course_Name
# 0         Yeng        1000       Goon1
# 1       Heesoo        1001       Goon2
# 2     Victoria        1002       Goon3
# 3          Cao        1003       Goon4
# 4         Luke        1004       Goon5>

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### I want to use another data set so I set mice as my variable and used,"pd.read_csv('name of file I want it to read')

# %%
mice = pd.read_csv("CFW.csv")

# %%
mice
# Out:
#           rfid     genot status Jan2026 sex        dob 01mo_test_date  \
# 0     CFW_0001  genotyped N1769 Jan2026   F   5/1/2020            NaN
# 1     CFW_0002  genotyped N1769 Jan2026   F   5/1/2020            NaN
# 2     CFW_0003  genotyped N1769 Jan2026   F   5/1/2020            NaN
# 3     CFW_0004  genotyped N1769 Jan2026   F   5/1/2020            NaN
# 4     CFW_0005  genotyped N1769 Jan2026   M   5/1/2020            NaN
# ...        ...                      ...  ..        ...            ...
# 2161  CFW_2208  genotyped N1769 Jan2026   M  8/27/2024            NaN
# 2162  CFW_2209  genotyped N1769 Jan2026   M  8/27/2024            NaN
# 2163  CFW_2210  genotyped N1769 Jan2026   M  8/27/2024            NaN
# 2164  CFW_2211  genotyped N1769 Jan2026   M  8/27/2024            NaN
# 2165  CFW_2212  genotyped N1769 Jan2026   M  8/27/2024            NaN
#
#      06mo_test_date 10mo_test_date 01mo_04_khz 01mo_08_khz 01mo_12_khz  ...  \
# ...

# %%
# Dataset we're using
df = pd.read_csv("CFW.csv")
# 1 Months
khz = [4, 8, 12, 16, 24, 32]
onemonth = ['01mo_04_khz', '01mo_08_khz', '01mo_12_khz', '01mo_16_khz', '01mo_24_khz', '01mo_32_khz']

deaf_counts = []
not_deaf_counts = []

for col in onemonth:
    valid_data = df[col].dropna()
    deaf = (valid_data == 'NR').sum()
    deaf_counts.append(deaf)
    not_deaf = (valid_data != 'NR').sum()
    not_deaf_counts.append(not_deaf)
    
# imaging
plt.bar(khz_labels, not_deaf_counts, color='blue', label='Not Deaf', width=2)
plt.bar(khz_labels, deaf_counts, bottom=not_deaf_counts, color='red', label='Deaf (NR)', width=2)

plt.xlabel('Frequency (khz)')
plt.ylabel('number of Mice')
plt.title('tested @ 1 month')
plt.xticks(khz) # Force the x-axis to only show your tested frequencies

plt.show()

# %%
# Dataset we're using
df = pd.read_csv("CFW.csv")
# 1 Months
khz = [4, 8, 12, 16, 24, 32]
onemonth = ['06mo_04_khz', '06mo_08_khz', '06mo_12_khz', '06mo_16_khz', '06mo_24_khz', '06mo_32_khz']

deaf_counts = []
not_deaf_counts = []

for col in onemonth:
    valid_data = df[col].dropna()
    deaf = (valid_data == 'NR').sum()
    deaf_counts.append(deaf)
    not_deaf = (valid_data != 'NR').sum()
    not_deaf_counts.append(not_deaf)
    
# imaging
plt.bar(khz_labels, not_deaf_counts, color='blue', label='Not Deaf', width=2)
plt.bar(khz_labels, deaf_counts, bottom=not_deaf_counts, color='red', label='Deaf (NR)', width=2)

plt.xlabel('Frequency (khz)')
plt.ylabel('number of Mice')
plt.title('tested @ 6 month')
plt.xticks(khz) # Force the x-axis to only show your tested frequencies
plt.legend()

plt.show()

# %%
# Dataset we're using
df = pd.read_csv("CFW.csv")
# 1 Months
khz = [4, 8, 12, 16, 24, 32]
onemonth = ['10mo_04_khz', '10mo_08_khz', '10mo_12_khz', '10mo_16_khz', '10mo_24_khz', '10mo_32_khz']

deaf_counts = []
not_deaf_counts = []

for col in onemonth:
    valid_data = df[col].dropna()
    deaf = (valid_data == 'NR').sum()
    deaf_counts.append(deaf)
    not_deaf = (valid_data != 'NR').sum()
    not_deaf_counts.append(not_deaf)
    
# imaging
plt.bar(khz_labels, not_deaf_counts, color='blue', label='Not Deaf', width=2)
plt.bar(khz_labels, deaf_counts, bottom=not_deaf_counts, color='red', label='Deaf (NR)', width=2)

plt.xlabel('Frequency (khz)')
plt.ylabel('number of Mice')
plt.title('tested @ 10 month')
plt.xticks(khz) # Force the x-axis to only show your tested frequencies
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. Load the data and setup constants
df = pd.read_csv("CFW.csv")
khz = [4, 8, 12, 16, 24, 32]
x_positions = np.arange(len(khz)) 
width = 0.35 

onemonth = ['01mo_04_khz', '01mo_08_khz', '01mo_12_khz', '01mo_16_khz', '01mo_24_khz', '01mo_32_khz'],
sixmonth = ['06mo_04_khz', '06mo_08_khz', '06mo_12_khz', '06mo_16_khz', '06mo_24_khz', '06mo_32_khz'],
tenmonths = ['10mo_04_khz', '10mo_08_khz', '10mo_12_khz', '10mo_16_khz', '10mo_24_khz', '10mo_32_khz']

# 3. Create the grid: 1 Row, 3 Columns. 
# figsize=(18, 5) makes the "poster board" wide enough to fit them all
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(5, 20))

# 4. Loop through the timepoints, plotting each one on a different axis
for i, (time_title, columns) in enumerate(timepoints.items()):
    
    # Grab the specific graph (0, 1, or 2)
    ax = axes[i] 
    
    deaf_counts = []
    not_deaf_counts = []

    # Calculate counts just like before
    for col in columns:
        valid_data = df[col].dropna()
        deaf_counts.append((valid_data == 'NR').sum())
        not_deaf_counts.append((valid_data != 'NR').sum())
    
    ax.bar(khz, not_deaf_counts, color='blue', label='Not Deaf', width=2)
    ax.bar(khz, deaf_counts, bottom=not_deaf_counts, color='red', label='Deaf (NR)', width=2)
    ax.set_xlabel('Frequency (kHz)')
    ax.set_ylabel('Number of Mice')

axes[2].legend()

plt.show()

# %% [markdown]
# ### Here I want to show the exact column that I want to view

# %%
df_sorted = mice.sort_values(by='01mo_04_khz')[['rfid','sex','01mo_04_khz']]
df.columns = df.columns.str.strip()

# %%
df_sorted
# Out:
#           rfid sex 01mo_04_khz
# 1679  CFW_1703   F        20.0
# 1680  CFW_1704   F        22.0
# 1692  CFW_1718   F        32.0
# 1919  CFW_1956   F        32.0
# 1695  CFW_1722   F        32.0
# ...        ...  ..         ...
# 2161  CFW_2208   M         NaN
# 2162  CFW_2209   M         NaN
# 2163  CFW_2210   M         NaN
# 2164  CFW_2211   M         NaN
# 2165  CFW_2212   M         NaN
#
# [2166 rows x 3 columns]

# %% [markdown]
# ### Here I wanted to see where in my dataset do I have the highest amount of khz

# %%
mice['01mo_04_khz'] = pd.to_numeric(mice['01mo_04_khz'], errors='coerce')
mice.nlargest(20,'01mo_04_khz')[['rfid','01mo_04_khz']]
# Out:
#           rfid  01mo_04_khz
# 810   CFW_0814         98.0
# 1502  CFW_1520         98.0
# 1517  CFW_1536         98.0
# 1627  CFW_1650         98.0
# 1823  CFW_1857         98.0
# 1240  CFW_1253         96.0
# 808   CFW_0812         95.0
# 1655  CFW_1679         94.0
# 723   CFW_0727         93.0
# 1574  CFW_1594         92.0
# 640   CFW_0644         91.0
# 921   CFW_0931         90.0
# 633   CFW_0637         89.0
# 1024  CFW_1034         89.0
# 661   CFW_0665         88.0
# 807   CFW_0811         88.0
# 1051  CFW_1061         88.0
# 1520  CFW_1539         87.0
# 1242  CFW_1255         86.0
# 1665  CFW_1689         86.0

# %%
mice
# Out:
# <bound method PlotAccessor.bar of <pandas.plotting.PlotAccessor object at 0x705a4a798d50>>
